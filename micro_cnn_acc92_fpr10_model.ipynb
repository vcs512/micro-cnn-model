# %% [markdown]
# <a href="https://colab.research.google.com/github/vcs512/micro-cnn-model/blob/main/micro_cnn_acc92_fpr10_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 0- Prepare enviroment

# %% [markdown]
# ## Create local dir paths for models

# %%
# Define paths to model files
import os
MODELS_DIR = 'models/'
if not os.path.exists(MODELS_DIR):
    os.mkdir(MODELS_DIR)
MODEL_TF = MODELS_DIR + 'model'
MODEL_NO_QUANT_TFLITE = MODELS_DIR + 'model_no_quant.tflite'
MODEL_TFLITE = MODELS_DIR + 'model.tflite'
MODEL_TFLITE_MICRO = MODELS_DIR + 'model.cc'

# %% [markdown]
# ## Setup Environment

# %% [markdown]
# ### Install Dependencies

# %%
! pip install tensorflow==2.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.4.0
#   Downloading tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
#      |████████████████████████████████| 394.7 MB 14 kB/s
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (3.17.3)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 40.4 MB/s
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 54.6 MB/s
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.37.1)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.1.2)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 49.9 MB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (0.2.0)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 38.5 MB/s
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.15.0)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0rc0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 48.9 MB/s
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (2.9.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.4.0) (1.6.3)
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (57.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.4->tensorflow==2.4.0) (0.4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.0) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.0) (3.2.2)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=68784c08c97f647c5d46dd0d7bc5bff8934e050c5e071179172185b16883c6dc
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68724 sha256=50133af45f96aef1fb4591b006387b12bc0f11b8d60840ba21886cc3a1c5c2a4
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built termcolor wrapt
# Installing collected packages: typing-extensions, numpy, grpcio, absl-py, wrapt, termcolor, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.50.0
#     Uninstalling grpcio-1.50.0:
#       Successfully uninstalled grpcio-1.50.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.3.0
#     Uninstalling absl-py-1.3.0:
#       Successfully uninstalled absl-py-1.3.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.0.1
#     Uninstalling termcolor-2.0.1:
#       Successfully uninstalled termcolor-2.0.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# pydantic 1.10.2 requires typing-extensions>=4.1.0, but you have typing-extensions 3.7.4.3 which is incompatible.
# jaxlib 0.3.22+cuda11.cudnn805 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# jax 0.3.23 requires numpy>=1.20, but you have numpy 1.19.5 which is incompatible.
# cmdstanpy 1.0.8 requires numpy>=1.21, but you have numpy 1.19.5 which is incompatible.
# Successfully installed absl-py-0.15.0 gast-0.3.3 grpcio-1.32.0 h5py-2.10.0 numpy-1.19.5 tensorflow-2.4.0 tensorflow-estimator-2.4.0 termcolor-1.1.0 typing-extensions-3.7.4.3 wrapt-1.12.1

# %% [markdown]
# ### Imports

# %%
# Machine learning library
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, AveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import plot_model

# Math library
import numpy as np
import math

# Data manipulation library
import pandas as pd

# Graphing and plot library
import matplotlib.pyplot as plt
import seaborn as sns

# Computer vision
import cv2 as cv

# %% [markdown]
# ### Configure standard seeds and plotting

# %%
# seed for RNG
seed = 2509
np.random.seed(seed)
tf.random.set_seed(seed)

# ploting
plt.rc('legend',fontsize='large')
plt.rc('lines', linewidth=2)
plt.rcParams.update({'axes.facecolor':'white'})

# %% [markdown]
# # 1- Training a micro-CNN
#
#
# The base in this notebook is based in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) example for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview).
#
# Builded to run on a ESP32 (TM).
#
# References:
#
# - https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world/train/train_hello_world_model.ipynb
# - https://www.kaggle.com/code/ginsaputra/visual-inspection-of-casting-products-using-cnn/notebook
# - https://www.kaggle.com/code/sfbruno/image-processing-cnn

# %% [markdown]
# ## Prepare Data for training

# %% [markdown]
# ### Observing dataset

# %%
# directories of dataset
dir_data = '/content/drive/MyDrive/TCC_VCS/dataset/resize-128'


dir_train = dir_data + '/train'
dir_train_util = dir_train + '/0_utilizavel'
dir_train_def = dir_train + '/1_defeituoso'

dir_test = dir_data + '/test'
dir_test_util = dir_test + '/0_utilizavel'
dir_test_def = dir_test + '/1_defeituoso'

# %%
# see samples
plt.figure(figsize=(15,15))


print('Amostra de utilizável =',dir_train_util+'/utiliza (1)')
plt.subplot(1,2,1)
sample_util = cv.imread(dir_train_util+'/utiliza (1).jpeg')
plt.imshow(sample_util, 'gray')
plt.title('Peça utilizável - classe 0')


print('Amostra de defeituosa =' ,dir_train_def+'/defeito (1)')
plt.subplot(122)
sample_def = cv.imread(dir_train_def+'/defeito (1).jpeg')
plt.imshow(sample_def, 'gray')
plt.title('Peça defeituosa - classe 1')

plt.show()
# Out:
# Amostra de utilizável = /content/drive/MyDrive/TCC_VCS/dataset/resize-128/train/0_utilizavel/utiliza (1)
# Amostra de defeituosa = /content/drive/MyDrive/TCC_VCS/dataset/resize-128/train/1_defeituoso/defeito (1)

# %% [markdown]
# ### Pre-processing function

# %%
# functiond to modify data before training
def pre_func(img):
  
  img.reshape(128,128)
  # Rotate
  rot = np.int8(4*np.random.rand())
  # print("rot =", rot)
  if rot>0:
    rot_func = [None, cv.ROTATE_90_CLOCKWISE, cv.ROTATE_180, cv.ROTATE_90_COUNTERCLOCKWISE]
    img = cv.rotate(img, rot_func[rot])


  # Zoom
  zoom = np.int8(3*np.random.rand())
  # print("zoom =", zoom)
  # r, c = img.shape
  r=128
  c=128
  zoom_func = np.array(np.array([1.0, 0.9, 0.8])*r, dtype=int)
  img = img[ (r-zoom_func[zoom])//2 : (r+zoom_func[zoom])//2, 
             (c-zoom_func[zoom])//2 : (c+zoom_func[zoom])//2]

  img = cv.resize(img, (r,c))
  img = img.reshape(128,128,1)


  return img

# %%
pre_path = dir_train_def+'/defeito ({}).jpeg'.format(23)
print(pre_path)

pre_test = cv.imread(pre_path, cv.IMREAD_GRAYSCALE)

plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(pre_test, 'gray')
plt.title('Amostra original', fontsize=15)

pre_test = pre_test.reshape( 128,128,1 )
tmp = pre_func(pre_test).reshape(128,128)
pre_test = tmp

plt.subplot(122)
plt.imshow(pre_test, 'gray')
plt.title('Amostra modificada', fontsize=15)
plt.show()
# Out:
# /content/drive/MyDrive/TCC_VCS/dataset/resize-128/train/1_defeituoso/defeito (23).jpeg

# %% [markdown]
# ### Data stream generators

# %%
# common arguments to generators
img_size = sample_util.shape[0:2]
batch_size = 32
rand_seed = 1

# %%
# training
arg_train = {'target_size': img_size,
             'color_mode': 'grayscale',
             'classes': {'0_utilizavel': 0,
                         '1_defeituoso': 1},
             'class_mode': 'binary',
             'batch_size': batch_size,
             'seed': rand_seed}

train_gen = ImageDataGenerator(
                                preprocessing_function=pre_func,
                                # 20% to validation
                                validation_split=0.2)

print('Training set: ')
train_set = train_gen.flow_from_directory(
    directory=dir_train, subset='training', **arg_train)
print(train_set.class_indices)


print('\nValidation set: ')
valid_set = train_gen.flow_from_directory(
    directory=dir_train, subset='validation', **arg_train)
print(valid_set.class_indices)
# Out:
# Training set:
# Found 937 images belonging to 2 classes.
# {'0_utilizavel': 0, '1_defeituoso': 1}
#
# Validation set:
# Found 234 images belonging to 2 classes.
# {'0_utilizavel': 0, '1_defeituoso': 1}

# %%
# Test
arg_test = {'target_size': img_size,
            'color_mode': 'grayscale',
             'classes': {'0_utilizavel': 0,
                         '1_defeituoso': 1},
            'class_mode': 'binary',
            'batch_size': batch_size,
            'seed': rand_seed,
            'shuffle': False}

test_gen = ImageDataGenerator( preprocessing_function=pre_func)

print('Testing set: ')
test_set = test_gen.flow_from_directory(
    directory=dir_test, **arg_test)
print(test_set.class_indices)
# Out:
# Testing set:
# Found 128 images belonging to 2 classes.
# {'0_utilizavel': 0, '1_defeituoso': 1}

# %% [markdown]
# ## Training

# %% [markdown]
# ### Create a model

# %%
# Define CNN model architecture

# options
k_pool = 2    # pooling kernel size
k_conv = 3    # convolution kernel size

n_filter = 2  # number of filters
reduc = 2     # stride reduction factor


# Modeling
cnn_model = Sequential()
# 128
cnn_model.add( Conv2D(filters=n_filter, kernel_size=(k_conv, k_conv), strides=1, activation='relu', padding='same', input_shape=img_size+(1,)) )
cnn_model.add( MaxPooling2D(pool_size=(k_pool, k_pool), strides=reduc) )

# 64
cnn_model.add( Conv2D(filters=2*n_filter, kernel_size=(k_conv, k_conv), strides=1, activation='relu', padding='same') )
cnn_model.add( MaxPooling2D(pool_size=(k_pool, k_pool), strides=reduc) )

# 32
cnn_model.add( Conv2D(filters=4*n_filter, kernel_size=(k_conv, k_conv), strides=1, activation='relu', padding='same') )
cnn_model.add( MaxPooling2D(pool_size=(k_pool, k_pool), strides=reduc) )
cnn_model.add( Dropout(.05) )

# 16
cnn_model.add( Conv2D(filters=4*n_filter, kernel_size=(k_conv, k_conv), strides=1, activation='relu', padding='same') )
cnn_model.add( MaxPooling2D(pool_size=(k_pool, k_pool), strides=reduc) )
cnn_model.add( Dropout(.01) )

# 8
# cnn_model.add( Conv2D(filters=16*n_filter, kernel_size=(k_conv, k_conv), strides=1, activation='relu', padding='same') )
cnn_model.add( Conv2D(filters=8*n_filter, kernel_size=(k_conv-2, k_conv-2), strides=1, activation='relu', padding='same') )
cnn_model.add( Dropout(.01) )

# Flatten
cnn_model.add( Flatten() )
cnn_model.add( Dense(1, activation='sigmoid') )


# Training parameters
  # Defaults
cnn_model.compile(
    optimizer=Adam(learning_rate=0.001),  
    loss='binary_crossentropy',
    metrics=['accuracy'])

# model architecture
cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 128, 128, 2)       20
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 64, 2)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 4)         76
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 32, 4)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 32, 32, 8)         296
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 16, 16, 8)         584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 8)           0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 8, 8, 16)          144
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 2,145
# Trainable params: 2,145
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Graphical model

# %%
plot_model(cnn_model, show_shapes=True, expand_nested=True, dpi=60)

# %% [markdown]
# ### A - Train

# %%
# Fit model using train and validation set
n_epochs = 300

history = cnn_model.fit(
            train_set,
            validation_data=valid_set,

            # training options
            epochs=n_epochs,
            batch_size=32,
            verbose=1,

            # save less validation loss
            callbacks=ModelCheckpoint(
                      'CNN_Casting_Inspection.hdf5',
                      save_best_only=True,
                      monitor='val_loss')
            )
    
cnn_model.save(MODEL_TF)
# Out:
# Epoch 1/300
# 30/30 [==============================] - 8s 233ms/step - loss: 0.9543 - accuracy: 0.5428 - val_loss: 0.6284 - val_accuracy: 0.6325
# Epoch 2/300
# 30/30 [==============================] - 7s 223ms/step - loss: 0.6173 - accuracy: 0.6484 - val_loss: 0.5904 - val_accuracy: 0.6838
# Epoch 3/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.6033 - accuracy: 0.6578 - val_loss: 0.5923 - val_accuracy: 0.6496
# Epoch 4/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.5746 - accuracy: 0.6752 - val_loss: 0.5586 - val_accuracy: 0.6923
# Epoch 5/300
# 30/30 [==============================] - 7s 223ms/step - loss: 0.5221 - accuracy: 0.7093 - val_loss: 0.5456 - val_accuracy: 0.7179
# Epoch 6/300
# 30/30 [==============================] - 7s 222ms/step - loss: 0.5378 - accuracy: 0.7214 - val_loss: 0.5551 - val_accuracy: 0.7179
# Epoch 7/300
# 30/30 [==============================] - 7s 224ms/step - loss: 0.5392 - accuracy: 0.7100 - val_loss: 0.5731 - val_accuracy: 0.7137
# Epoch 8/300
# 30/30 [==============================] - 7s 220ms/step - loss: 0.5273 - accuracy: 0.7245 - val_loss: 0.5547 - val_accuracy: 0.6838
# Epoch 9/300
# 30/30 [==============================] - 7s 224ms/step - loss: 0.5207 - accuracy: 0.7341 - val_loss: 0.5774 - val_accuracy: 0.7179
# Epoch 10/300
# 30/30 [==============================] - 7s 223ms/step - loss: 0.5180 - accuracy: 0.7558 - val_loss: 0.5153 - val_accuracy: 0.7308
# Epoch 11/300
# 30/30 [==============================] - 7s 222ms/step - loss: 0.5135 - accuracy: 0.7271 - val_loss: 0.5225 - val_accuracy: 0.7308
# Epoch 12/300
# 30/30 [==============================] - 7s 223ms/step - loss: 0.4935 - accuracy: 0.7629 - val_loss: 0.5503 - val_accuracy: 0.7179
# Epoch 13/300
# 30/30 [==============================] - 7s 224ms/step - loss: 0.4700 - accuracy: 0.7933 - val_loss: 0.5286 - val_accuracy: 0.7308
# Epoch 14/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.4886 - accuracy: 0.7592 - val_loss: 0.5964 - val_accuracy: 0.7137
# Epoch 15/300
# 30/30 [==============================] - 7s 225ms/step - loss: 0.5056 - accuracy: 0.7467 - val_loss: 0.5232 - val_accuracy: 0.7350
# Epoch 16/300
# 30/30 [==============================] - 7s 225ms/step - loss: 0.4905 - accuracy: 0.7627 - val_loss: 0.5612 - val_accuracy: 0.7222
# Epoch 17/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.4776 - accuracy: 0.7677 - val_loss: 0.5457 - val_accuracy: 0.7436
# Epoch 18/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.4934 - accuracy: 0.7429 - val_loss: 0.5241 - val_accuracy: 0.7350
# Epoch 19/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.4916 - accuracy: 0.7200 - val_loss: 0.5202 - val_accuracy: 0.7137
# Epoch 20/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.4655 - accuracy: 0.7700 - val_loss: 0.5276 - val_accuracy: 0.7094
# Epoch 21/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.4644 - accuracy: 0.7818 - val_loss: 0.5134 - val_accuracy: 0.7650
# Epoch 22/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.4600 - accuracy: 0.7831 - val_loss: 0.5241 - val_accuracy: 0.7607
# Epoch 23/300
# 30/30 [==============================] - 7s 225ms/step - loss: 0.4413 - accuracy: 0.8059 - val_loss: 0.5111 - val_accuracy: 0.7650
# Epoch 24/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.4485 - accuracy: 0.7799 - val_loss: 0.4843 - val_accuracy: 0.7650
# Epoch 25/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.4505 - accuracy: 0.8085 - val_loss: 0.4720 - val_accuracy: 0.7692
# Epoch 26/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.4519 - accuracy: 0.7817 - val_loss: 0.5411 - val_accuracy: 0.7179
# Epoch 27/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.4166 - accuracy: 0.8019 - val_loss: 0.4868 - val_accuracy: 0.7778
# Epoch 28/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.4767 - accuracy: 0.7610 - val_loss: 0.5655 - val_accuracy: 0.7650
# Epoch 29/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.4539 - accuracy: 0.7934 - val_loss: 0.4943 - val_accuracy: 0.7778
# Epoch 30/300
# 30/30 [==============================] - 7s 225ms/step - loss: 0.4177 - accuracy: 0.7977 - val_loss: 0.4883 - val_accuracy: 0.7564
# Epoch 31/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.4137 - accuracy: 0.8193 - val_loss: 0.4621 - val_accuracy: 0.7735
# Epoch 32/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.3942 - accuracy: 0.8153 - val_loss: 0.4508 - val_accuracy: 0.7949
# Epoch 33/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.4093 - accuracy: 0.8123 - val_loss: 0.4552 - val_accuracy: 0.7991
# Epoch 113/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2544 - accuracy: 0.8856 - val_loss: 0.2673 - val_accuracy: 0.8974
# Epoch 114/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2536 - accuracy: 0.8987 - val_loss: 0.2446 - val_accuracy: 0.9017
# Epoch 115/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.2997 - accuracy: 0.8790 - val_loss: 0.3528 - val_accuracy: 0.8547
# Epoch 116/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2597 - accuracy: 0.9053 - val_loss: 0.2978 - val_accuracy: 0.8718
# Epoch 117/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2625 - accuracy: 0.8986 - val_loss: 0.2892 - val_accuracy: 0.8846
# Epoch 118/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2425 - accuracy: 0.8956 - val_loss: 0.3417 - val_accuracy: 0.8504
# Epoch 119/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.3515 - accuracy: 0.8570 - val_loss: 0.2703 - val_accuracy: 0.8932
# Epoch 120/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.3122 - accuracy: 0.8604 - val_loss: 0.2868 - val_accuracy: 0.8803
# Epoch 121/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2688 - accuracy: 0.8946 - val_loss: 0.2896 - val_accuracy: 0.8718
# Epoch 122/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.2917 - accuracy: 0.8735 - val_loss: 0.3497 - val_accuracy: 0.8590
# Epoch 123/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2499 - accuracy: 0.9021 - val_loss: 0.3541 - val_accuracy: 0.8590
# Epoch 124/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2980 - accuracy: 0.8866 - val_loss: 0.2998 - val_accuracy: 0.8803
# Epoch 125/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2413 - accuracy: 0.8903 - val_loss: 0.3276 - val_accuracy: 0.8803
# Epoch 126/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2400 - accuracy: 0.8906 - val_loss: 0.2576 - val_accuracy: 0.8974
# Epoch 127/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2608 - accuracy: 0.8832 - val_loss: 0.3259 - val_accuracy: 0.8846
# Epoch 128/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2899 - accuracy: 0.8711 - val_loss: 0.3349 - val_accuracy: 0.8632
# Epoch 129/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2774 - accuracy: 0.8825 - val_loss: 0.2970 - val_accuracy: 0.8803
# Epoch 130/300
# 30/30 [==============================] - 7s 233ms/step - loss: 0.2529 - accuracy: 0.8784 - val_loss: 0.4028 - val_accuracy: 0.7991
# Epoch 131/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2730 - accuracy: 0.8933 - val_loss: 0.3503 - val_accuracy: 0.8590
# Epoch 132/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2744 - accuracy: 0.8764 - val_loss: 0.2708 - val_accuracy: 0.8974
# Epoch 133/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2630 - accuracy: 0.8821 - val_loss: 0.3319 - val_accuracy: 0.8547
# Epoch 134/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2688 - accuracy: 0.8941 - val_loss: 0.2761 - val_accuracy: 0.8974
# Epoch 135/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2873 - accuracy: 0.8715 - val_loss: 0.3092 - val_accuracy: 0.8590
# Epoch 136/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2360 - accuracy: 0.9091 - val_loss: 0.2549 - val_accuracy: 0.8889
# Epoch 137/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2355 - accuracy: 0.9083 - val_loss: 0.3541 - val_accuracy: 0.8248
# Epoch 138/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2835 - accuracy: 0.8801 - val_loss: 0.2862 - val_accuracy: 0.8718
# Epoch 139/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2331 - accuracy: 0.9044 - val_loss: 0.3096 - val_accuracy: 0.8590
# Epoch 140/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2699 - accuracy: 0.8733 - val_loss: 0.2890 - val_accuracy: 0.8761
# Epoch 141/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2547 - accuracy: 0.8975 - val_loss: 0.2569 - val_accuracy: 0.9103
# Epoch 142/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.2639 - accuracy: 0.9004 - val_loss: 0.3115 - val_accuracy: 0.8761
# Epoch 143/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2577 - accuracy: 0.8984 - val_loss: 0.3100 - val_accuracy: 0.8803
# Epoch 144/300
# 30/30 [==============================] - 10s 324ms/step - loss: 0.2825 - accuracy: 0.8767 - val_loss: 0.3430 - val_accuracy: 0.8504
# Epoch 145/300
# 30/30 [==============================] - 7s 238ms/step - loss: 0.2365 - accuracy: 0.9042 - val_loss: 0.3029 - val_accuracy: 0.8718
# Epoch 146/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2270 - accuracy: 0.9097 - val_loss: 0.3280 - val_accuracy: 0.8761
# Epoch 147/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2871 - accuracy: 0.8743 - val_loss: 0.3470 - val_accuracy: 0.8632
# Epoch 148/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2122 - accuracy: 0.9197 - val_loss: 0.2949 - val_accuracy: 0.8632
# Epoch 149/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2539 - accuracy: 0.8920 - val_loss: 0.3476 - val_accuracy: 0.8846
# Epoch 150/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2799 - accuracy: 0.8836 - val_loss: 0.3266 - val_accuracy: 0.8803
# Epoch 151/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2431 - accuracy: 0.8928 - val_loss: 0.3238 - val_accuracy: 0.8718
# Epoch 152/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2041 - accuracy: 0.9161 - val_loss: 0.2967 - val_accuracy: 0.8718
# Epoch 153/300
# 30/30 [==============================] - 7s 232ms/step - loss: 0.2568 - accuracy: 0.8871 - val_loss: 0.3271 - val_accuracy: 0.8632
# Epoch 154/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2617 - accuracy: 0.8776 - val_loss: 0.3328 - val_accuracy: 0.8846
# Epoch 155/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2682 - accuracy: 0.8887 - val_loss: 0.3152 - val_accuracy: 0.8547
# Epoch 156/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2388 - accuracy: 0.8898 - val_loss: 0.2447 - val_accuracy: 0.9017
# Epoch 157/300
# 30/30 [==============================] - 7s 226ms/step - loss: 0.2392 - accuracy: 0.8954 - val_loss: 0.2241 - val_accuracy: 0.9274
# Epoch 158/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2296 - accuracy: 0.9011 - val_loss: 0.3327 - val_accuracy: 0.8889
# Epoch 159/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2819 - accuracy: 0.8692 - val_loss: 0.3275 - val_accuracy: 0.8803
# Epoch 160/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2550 - accuracy: 0.8992 - val_loss: 0.2635 - val_accuracy: 0.8974
# Epoch 161/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2626 - accuracy: 0.8938 - val_loss: 0.2723 - val_accuracy: 0.9060
# Epoch 162/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2561 - accuracy: 0.8952 - val_loss: 0.3268 - val_accuracy: 0.8803
# Epoch 163/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2495 - accuracy: 0.8962 - val_loss: 0.2748 - val_accuracy: 0.8718
# Epoch 164/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2857 - accuracy: 0.8928 - val_loss: 0.3221 - val_accuracy: 0.8761
# Epoch 165/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2741 - accuracy: 0.8831 - val_loss: 0.2782 - val_accuracy: 0.9103
# Epoch 166/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2261 - accuracy: 0.8960 - val_loss: 0.2855 - val_accuracy: 0.8718
# Epoch 167/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2265 - accuracy: 0.9149 - val_loss: 0.2876 - val_accuracy: 0.8803
# Epoch 168/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2328 - accuracy: 0.8979 - val_loss: 0.2575 - val_accuracy: 0.9103
# Epoch 169/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2564 - accuracy: 0.8977 - val_loss: 0.3240 - val_accuracy: 0.8547
# Epoch 170/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2121 - accuracy: 0.9219 - val_loss: 0.2725 - val_accuracy: 0.8974
# Epoch 171/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2350 - accuracy: 0.8950 - val_loss: 0.3642 - val_accuracy: 0.8462
# Epoch 172/300
# Epoch 192/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2298 - accuracy: 0.9104 - val_loss: 0.2748 - val_accuracy: 0.8803
# Epoch 193/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2186 - accuracy: 0.9111 - val_loss: 0.2575 - val_accuracy: 0.8932
# Epoch 194/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2448 - accuracy: 0.9024 - val_loss: 0.3447 - val_accuracy: 0.8761
# Epoch 195/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2252 - accuracy: 0.8977 - val_loss: 0.3465 - val_accuracy: 0.8675
# Epoch 196/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2409 - accuracy: 0.9015 - val_loss: 0.3492 - val_accuracy: 0.8590
# Epoch 197/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2211 - accuracy: 0.9174 - val_loss: 0.2918 - val_accuracy: 0.8718
# Epoch 198/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2560 - accuracy: 0.8854 - val_loss: 0.2721 - val_accuracy: 0.9017
# Epoch 199/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2344 - accuracy: 0.9106 - val_loss: 0.2774 - val_accuracy: 0.9017
# Epoch 200/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2320 - accuracy: 0.8961 - val_loss: 0.2542 - val_accuracy: 0.9145
# Epoch 201/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2389 - accuracy: 0.9026 - val_loss: 0.2712 - val_accuracy: 0.8718
# Epoch 202/300
# 30/30 [==============================] - 7s 233ms/step - loss: 0.1958 - accuracy: 0.9094 - val_loss: 0.2286 - val_accuracy: 0.9103
# Epoch 203/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2285 - accuracy: 0.8884 - val_loss: 0.2361 - val_accuracy: 0.9017
# Epoch 204/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2389 - accuracy: 0.9001 - val_loss: 0.2469 - val_accuracy: 0.9017
# Epoch 205/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2357 - accuracy: 0.9030 - val_loss: 0.3085 - val_accuracy: 0.8889
# Epoch 206/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2530 - accuracy: 0.8929 - val_loss: 0.2615 - val_accuracy: 0.8932
# Epoch 207/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2516 - accuracy: 0.9023 - val_loss: 0.2524 - val_accuracy: 0.8932
# Epoch 208/300
# 30/30 [==============================] - 10s 334ms/step - loss: 0.2482 - accuracy: 0.8969 - val_loss: 0.2796 - val_accuracy: 0.8846
# Epoch 209/300
# 30/30 [==============================] - 7s 234ms/step - loss: 0.2333 - accuracy: 0.8984 - val_loss: 0.2660 - val_accuracy: 0.8590
# Epoch 210/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2172 - accuracy: 0.9152 - val_loss: 0.3218 - val_accuracy: 0.8803
# Epoch 211/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2178 - accuracy: 0.9193 - val_loss: 0.2811 - val_accuracy: 0.8889
# Epoch 232/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2076 - accuracy: 0.9205 - val_loss: 0.2330 - val_accuracy: 0.9017
# Epoch 233/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2032 - accuracy: 0.9208 - val_loss: 0.2897 - val_accuracy: 0.8889
# Epoch 234/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2439 - accuracy: 0.8992 - val_loss: 0.2479 - val_accuracy: 0.9103
# Epoch 235/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2324 - accuracy: 0.9055 - val_loss: 0.2821 - val_accuracy: 0.8974
# Epoch 236/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.1770 - accuracy: 0.9343 - val_loss: 0.2539 - val_accuracy: 0.8974
# Epoch 237/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.2100 - accuracy: 0.9135 - val_loss: 0.3205 - val_accuracy: 0.8718
# Epoch 238/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2139 - accuracy: 0.9245 - val_loss: 0.2925 - val_accuracy: 0.8675
# Epoch 239/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2075 - accuracy: 0.9197 - val_loss: 0.2112 - val_accuracy: 0.8974
# Epoch 240/300
# 30/30 [==============================] - 10s 335ms/step - loss: 0.2708 - accuracy: 0.8874 - val_loss: 0.3692 - val_accuracy: 0.8419
# Epoch 241/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2325 - accuracy: 0.8944 - val_loss: 0.2779 - val_accuracy: 0.8889
# Epoch 242/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.1809 - accuracy: 0.9377 - val_loss: 0.3318 - val_accuracy: 0.8547
# Epoch 243/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.1944 - accuracy: 0.9275 - val_loss: 0.2021 - val_accuracy: 0.9316
# Epoch 244/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.1936 - accuracy: 0.9161 - val_loss: 0.2449 - val_accuracy: 0.9188
# Epoch 245/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2516 - accuracy: 0.8963 - val_loss: 0.2486 - val_accuracy: 0.9060
# Epoch 246/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2042 - accuracy: 0.9281 - val_loss: 0.2200 - val_accuracy: 0.9017
# Epoch 247/300
# 30/30 [==============================] - 7s 235ms/step - loss: 0.2454 - accuracy: 0.8878 - val_loss: 0.2561 - val_accuracy: 0.9060
# Epoch 248/300
# 30/30 [==============================] - 7s 227ms/step - loss: 0.1975 - accuracy: 0.9152 - val_loss: 0.2031 - val_accuracy: 0.9145
# Epoch 249/300
# 30/30 [==============================] - 7s 232ms/step - loss: 0.2437 - accuracy: 0.9090 - val_loss: 0.2464 - val_accuracy: 0.9145
# Epoch 250/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2088 - accuracy: 0.9115 - val_loss: 0.2348 - val_accuracy: 0.9231
# Epoch 251/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2163 - accuracy: 0.9202 - val_loss: 0.3743 - val_accuracy: 0.8462
# Epoch 252/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2350 - accuracy: 0.9122 - val_loss: 0.2581 - val_accuracy: 0.9060
# Epoch 253/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.2407 - accuracy: 0.8746 - val_loss: 0.3157 - val_accuracy: 0.8932
# Epoch 254/300
# 30/30 [==============================] - 7s 228ms/step - loss: 0.1944 - accuracy: 0.9169 - val_loss: 0.3386 - val_accuracy: 0.8803
# Epoch 255/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2081 - accuracy: 0.9058 - val_loss: 0.3457 - val_accuracy: 0.8632
# Epoch 256/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1867 - accuracy: 0.9101 - val_loss: 0.2879 - val_accuracy: 0.8889
# Epoch 257/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.1929 - accuracy: 0.9100 - val_loss: 0.2287 - val_accuracy: 0.8932
# Epoch 258/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1970 - accuracy: 0.9139 - val_loss: 0.2441 - val_accuracy: 0.9060
# Epoch 259/300
# 30/30 [==============================] - 7s 232ms/step - loss: 0.1999 - accuracy: 0.9195 - val_loss: 0.2241 - val_accuracy: 0.9017
# Epoch 260/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2251 - accuracy: 0.9036 - val_loss: 0.3207 - val_accuracy: 0.8761
# Epoch 261/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1994 - accuracy: 0.9128 - val_loss: 0.2624 - val_accuracy: 0.8846
# Epoch 262/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2094 - accuracy: 0.9051 - val_loss: 0.2686 - val_accuracy: 0.8846
# Epoch 263/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2112 - accuracy: 0.9178 - val_loss: 0.3095 - val_accuracy: 0.8803
# Epoch 264/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1848 - accuracy: 0.9165 - val_loss: 0.2448 - val_accuracy: 0.9103
# Epoch 265/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2125 - accuracy: 0.9051 - val_loss: 0.2947 - val_accuracy: 0.8846
# Epoch 266/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.2029 - accuracy: 0.9097 - val_loss: 0.2483 - val_accuracy: 0.8846
# Epoch 267/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1990 - accuracy: 0.9174 - val_loss: 0.2021 - val_accuracy: 0.9316
# Epoch 268/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1896 - accuracy: 0.9270 - val_loss: 0.2505 - val_accuracy: 0.8974
# Epoch 269/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2322 - accuracy: 0.9016 - val_loss: 0.3008 - val_accuracy: 0.8590
# Epoch 270/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.1951 - accuracy: 0.9154 - val_loss: 0.2721 - val_accuracy: 0.9103
# Epoch 271/300
# 30/30 [==============================] - 9s 306ms/step - loss: 0.2104 - accuracy: 0.9257 - val_loss: 0.3000 - val_accuracy: 0.8846
# Epoch 272/300
# 30/30 [==============================] - 8s 256ms/step - loss: 0.2240 - accuracy: 0.8968 - val_loss: 0.2847 - val_accuracy: 0.8761
# Epoch 273/300
# 30/30 [==============================] - 7s 233ms/step - loss: 0.1859 - accuracy: 0.9207 - val_loss: 0.2434 - val_accuracy: 0.8932
# Epoch 274/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1890 - accuracy: 0.9178 - val_loss: 0.3102 - val_accuracy: 0.8675
# Epoch 275/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2746 - accuracy: 0.8861 - val_loss: 0.2732 - val_accuracy: 0.8889
# Epoch 276/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1949 - accuracy: 0.9200 - val_loss: 0.2852 - val_accuracy: 0.8590
# Epoch 277/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2238 - accuracy: 0.9167 - val_loss: 0.2626 - val_accuracy: 0.9103
# Epoch 278/300
# 30/30 [==============================] - 7s 232ms/step - loss: 0.1822 - accuracy: 0.9262 - val_loss: 0.2700 - val_accuracy: 0.8632
# Epoch 279/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2319 - accuracy: 0.9081 - val_loss: 0.2927 - val_accuracy: 0.8803
# Epoch 280/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1792 - accuracy: 0.9273 - val_loss: 0.2379 - val_accuracy: 0.8974
# Epoch 281/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2237 - accuracy: 0.8981 - val_loss: 0.2078 - val_accuracy: 0.9188
# Epoch 282/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2010 - accuracy: 0.9216 - val_loss: 0.3032 - val_accuracy: 0.8803
# Epoch 283/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2219 - accuracy: 0.9157 - val_loss: 0.1960 - val_accuracy: 0.9231
# Epoch 284/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1997 - accuracy: 0.8989 - val_loss: 0.2791 - val_accuracy: 0.8718
# Epoch 285/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2196 - accuracy: 0.9083 - val_loss: 0.2242 - val_accuracy: 0.8974
# Epoch 286/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2289 - accuracy: 0.9170 - val_loss: 0.2370 - val_accuracy: 0.8974
# Epoch 287/300
# 30/30 [==============================] - 13s 423ms/step - loss: 0.2251 - accuracy: 0.9020 - val_loss: 0.2558 - val_accuracy: 0.9017
# Epoch 288/300
# 30/30 [==============================] - 8s 255ms/step - loss: 0.1915 - accuracy: 0.9188 - val_loss: 0.2389 - val_accuracy: 0.9231
# Epoch 289/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2242 - accuracy: 0.8954 - val_loss: 0.1973 - val_accuracy: 0.9145
# Epoch 290/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2193 - accuracy: 0.9169 - val_loss: 0.2325 - val_accuracy: 0.9145
# Epoch 291/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1782 - accuracy: 0.9355 - val_loss: 0.3633 - val_accuracy: 0.8376
# Epoch 292/300
# 30/30 [==============================] - 7s 233ms/step - loss: 0.2223 - accuracy: 0.9042 - val_loss: 0.2890 - val_accuracy: 0.8675
# Epoch 293/300
# 30/30 [==============================] - 7s 232ms/step - loss: 0.2084 - accuracy: 0.9135 - val_loss: 0.2435 - val_accuracy: 0.8974
# Epoch 294/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2157 - accuracy: 0.9282 - val_loss: 0.2904 - val_accuracy: 0.8889
# Epoch 295/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.2143 - accuracy: 0.9152 - val_loss: 0.2487 - val_accuracy: 0.8803
# Epoch 296/300
# 30/30 [==============================] - 7s 234ms/step - loss: 0.1704 - accuracy: 0.9384 - val_loss: 0.2669 - val_accuracy: 0.8846
# Epoch 297/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.2083 - accuracy: 0.8971 - val_loss: 0.2983 - val_accuracy: 0.8761
# Epoch 298/300
# 30/30 [==============================] - 7s 231ms/step - loss: 0.1632 - accuracy: 0.9489 - val_loss: 0.2903 - val_accuracy: 0.8632
# Epoch 299/300
# 30/30 [==============================] - 7s 229ms/step - loss: 0.1815 - accuracy: 0.9250 - val_loss: 0.2186 - val_accuracy: 0.9188
# Epoch 300/300
# 30/30 [==============================] - 7s 230ms/step - loss: 0.1994 - accuracy: 0.9296 - val_loss: 0.2745 - val_accuracy: 0.9017

# %% [markdown]
# ### Train metrics

# %%
# Prepare history
histo_dict = cnn_model.history.history
histo_df = pd.DataFrame(histo_dict, index=range(1,n_epochs+1))

# Plot metrics
fig, ax = plt.subplots(figsize=(15,10))
for m in histo_df.columns:
    ax.plot(histo_df.index, m, data=histo_df)

ax.set_xlabel('Época', fontsize=18)
ax.set_title('Métricas de treino', weight='bold', fontsize=22)
ax.legend(fontsize=18)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.grid()
plt.ylim([0,1])
plt.show()

# %% [markdown]
# ### Test metrics

# %% [markdown]
# #### Apply test set

# %%
best_model = load_model('./CNN_Casting_Inspection.hdf5')

# inference in test set
y_pred_prob = best_model.predict(test_set, verbose=1)
y_pred = (y_pred_prob >= 0.5).reshape(-1,)
y_true = test_set.classes[test_set.index_array]
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f89086a4200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 1s 104ms/step

# %% [markdown]
# #### B - ACC and FPR

# %%
# ACCURACY
                                 #( where diference exists        )
accuracy = 1 -  ( np.count_nonzero(np.int8(y_true)-np.int8(y_pred))  / len(y_pred) )
accuracy = accuracy*100
print('Accuracy = ', accuracy, '%' )


# FALSE POSITIVE RATE
coded = np.int8(y_true)-np.int8(y_pred)
#  * 0  : OK
#  * -1 : ok tagged as defect
#  ** 1 : defect not spotted
  # print(np.int8(y_true)-np.int8(y_pred))

defeituosas = np.count_nonzero(np.int8(y_true))
print('\nTotal Defective (1) number = ', defeituosas)

false_positive = np.count_nonzero( coded==1 )
fpr = 100* (false_positive / defeituosas)
print('False Positive Rate = ', fpr, '%')

# see false positives
inicia_defeitos = 704
class_0_test = np.count_nonzero( np.int8(y_true)==0 ) # find total usable
offset = inicia_defeitos-class_0_test # jump to test numeration, not include usable
# aware of OFFSET:
false_p_id = np.argwhere( coded==1 ).reshape(1,false_positive) + offset
false_p_id = false_p_id[0]
print('False positives ID =', false_p_id)
# Out:
# Accuracy =  92.1875 %
#
# Total Defective (1) number =  77
# False Positive Rate =  10.38961038961039 %
# False positives ID = [704 715 719 721 734 743 761 778]

# %% [markdown]
# #### See false positives

# %%
for errada in false_p_id:
  plt.figure(figsize=(7,7))
  false_p = cv.imread(dir_test_def+'/defeito ({}).jpeg'.format(errada))
  plt.title("Amostra defeituosa ({})".format(errada), fontsize=18)
  plt.imshow(false_p, 'gray')

# %% [markdown]
# #### Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax = sns.heatmap(confusion_matrix(y_true,y_pred), annot=True,
                 annot_kws={'size':14, 'weight':'bold'},
                 fmt='d', cbar=False, cmap='Blues')

ax.set_xticklabels(['Utilizável', 'Defeituosa'])
ax.set_yticklabels(['Utilizável', 'Defeituosa'], va='center')
plt.tick_params(axis='both', labelsize=14, length=0)
plt.ylabel('Esperado', size=14, weight='bold')
plt.xlabel('Inferido', size=14, weight='bold')
plt.show()

# Look at left down

# %% [markdown]
# ## Generate a TensorFlow Lite Model

# %% [markdown]
# ### TFlite Models with or without Quantization

# %% [markdown]
# #### No-quant

# %%
from tensorflow.python.keras.backend import dtype
# Convert the model to the TensorFlow Lite format without quantization
converter = tf.lite.TFLiteConverter.from_saved_model(MODEL_TF)
model_no_quant_tflite = converter.convert()

# Save the model to disk
open(MODEL_NO_QUANT_TFLITE, "wb").write(model_no_quant_tflite)

interpreter = tf.lite.Interpreter(model_content=model_no_quant_tflite)
input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

print(input_details)
print(output_details)
# Out:
# {'name': 'serving_default_conv2d_10_input:0', 'index': 0, 'shape': array([  1, 128, 128,   1], dtype=int32), 'shape_signature': array([ -1, 128, 128,   1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'StatefulPartitionedCall:0', 'index': 25, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([-1,  1], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}

# %% [markdown]
# #### Quantization: int8

# %%
# Convert the model to the TensorFlow Lite format with quantization
def representative_dataset():
  # for i in range(2):
  #   if i == 0:
  #     yield([ np.float32(np.zeros( (128,128) ).reshape(-1, *img_size , 1))])
  #   if i == 1:
  #     yield([ np.float32(255*np.ones( (128,128) ).reshape(-1, *img_size , 1)) ] )
  
  for path in train_set.filepaths:
    tmp = np.float32(cv.imread(path, cv.IMREAD_GRAYSCALE) )
    # tmp = pre_func(tmp)
    yield([ tmp.reshape(-1, *img_size , 1)])


# Set the optimization flag.
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Enforce integer only quantization
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

# Type of input/output
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

# Provide a representative dataset to ensure we quantize correctly.
converter.representative_dataset = representative_dataset
model_tflite = converter.convert()

# Save the model to disk
open(MODEL_TFLITE, "wb").write(model_tflite)


interpreter = tf.lite.Interpreter(model_content=model_tflite)
input_details = interpreter.get_input_details()[0]
output_details = interpreter.get_output_details()[0]

print('\n', input_details)
print(output_details)
# Out:
#  {'name': 'serving_default_conv2d_10_input:0_int8', 'index': 0, 'shape': array([  1, 128, 128,   1], dtype=int32), 'shape_signature': array([ -1, 128, 128,   1], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (1.0, -128), 'quantization_parameters': {'scales': array([1.], dtype=float32), 'zero_points': array([-128], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}
# {'name': 'StatefulPartitionedCall:0_int8', 'index': 25, 'shape': array([1, 1], dtype=int32), 'shape_signature': array([-1,  1], dtype=int32), 'dtype': <class 'numpy.int8'>, 'quantization': (0.00390625, -128), 'quantization_parameters': {'scales': array([0.00390625], dtype=float32), 'zero_points': array([-128], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}

# %% [markdown]
# ### Compare Model Performance

# %%
def predict_tflite(tflite_model, x_test):
  # Prepare the test data
  x_test_ = x_test.copy()
  x_test_ = x_test_
  x_test_ = x_test_.astype(np.float32)

  # Initialize the TFLite interpreter
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # Quantize the input layer
  input_scale, input_zero_point = input_details["quantization"]
  if (input_scale, input_zero_point) != (0.0, 0):
    x_test_ = x_test_ / input_scale + input_zero_point
    x_test_ = x_test_.astype(input_details["dtype"])
  
  # Invoke the interpreter
  y_pred = np.empty(x_test_.size, dtype=output_details["dtype"])
  for i in range(len(x_test_)):
    interpreter.set_tensor(input_details["index"], [x_test_[i]])
    interpreter.invoke()
    y_pred[i] = interpreter.get_tensor(output_details["index"])[0]
  
  # Dequantize the output layer
  output_scale, output_zero_point = output_details["quantization"]
  if (output_scale, output_zero_point) != (0.0, 0):
    y_pred = y_pred.astype(np.float32)
    y_pred = (y_pred - output_zero_point) * output_scale

  return y_pred

# %% [markdown]
# #### C - New accuracy and FPR

# %%
qt_y_pred = list()
qt_y_pred_prob = list()

# Calculate predictions for test set
for path in test_set.filepaths:
  img = cv.imread(path, cv.IMREAD_GRAYSCALE).reshape(-1, *img_size, 1)

  qt_y_pred_prob.append( predict_tflite(model_tflite, img)[0] )
  qt_y_pred_tmp = (qt_y_pred_prob[-1] >= 0.5).reshape(-1,)
  qt_y_pred.append( qt_y_pred_tmp )

qt_y_pred = np.array(qt_y_pred)

# ground truth
y_true = test_set.classes[test_set.index_array].reshape(len(y_true),1)

# %%
# ACCURACY
                                    #( where diference exists          )
qt_accuracy = 1 -  ( np.count_nonzero(np.int8(y_true)-np.int8(qt_y_pred))  / len(qt_y_pred) )
qt_accuracy = qt_accuracy*100
print('Quantized accuracy = ', qt_accuracy, '%' )


# FALSE POSITIVE RATE
qt_coded = (np.int8(y_true)-np.int8(qt_y_pred))
qt_coded = qt_coded.reshape(-1,)
#  * 0  : OK
#  * -1 : ok tagged as defect
#  ** 1 : defect not spotted
  # print(np.int8(y_true)-np.int8(y_pred))

qt_defeituosas = np.count_nonzero(np.int8(y_true))
print('\nTotal Defective number = ', defeituosas)

qt_false_positive = np.count_nonzero( qt_coded==1 )
qt_fpr = 100* (qt_false_positive / qt_defeituosas)
print('False Positive Rate = ', qt_fpr, '%')

# see false positives
inicia_defeitos = 704
class_0_test = np.count_nonzero( np.int8(y_true)==0 ) # find total usable
offset = inicia_defeitos-class_0_test # jump to test numeration, not include usable
# aware of OFFSET:
qt_false_p_id = np.argwhere( qt_coded==1 ).reshape(1,qt_false_positive) + offset
qt_false_p_id = qt_false_p_id[0]
print('False positives ID =', qt_false_p_id)
# Out:
# Quantized accuracy =  93.75 %
#
# Total Defective number =  77
# False Positive Rate =  6.493506493506493 %
# False positives ID = [734 743 751 761 764]

# %% [markdown]
# #### See false positives

# %%
for errada in qt_false_p_id:
  plt.figure(figsize=(7,7))
  false_p = cv.imread(dir_test_def+'/defeito ({}).jpeg'.format(errada))
  plt.title("Amostra defeituosa ({})".format(errada), fontsize=18)
  plt.imshow(false_p, 'gray')

# %% [markdown]
# #### Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax = sns.heatmap(confusion_matrix(y_true,qt_y_pred), annot=True,
                 annot_kws={'size':14, 'weight':'bold'},
                 fmt='d', cbar=False, cmap='Blues')

ax.set_xticklabels(['Utilizável', 'Defeituosa'])
ax.set_yticklabels(['Utilizável', 'Defeituosa'], va='center')
plt.tick_params(axis='both', labelsize=14, length=0)
plt.ylabel('Esperado', size=14, weight='bold')
plt.xlabel('Inferido', size=14, weight='bold')
plt.show()

# Look at left down

# %% [markdown]
# #### D - PoC

# %%
# Calculate predictions

y_test_pred_tf = list()
y_test_pred_no_quant_tflite = list()
y_test_pred_tflite = list()

test = 704 # begin of defectives in test
fator = 4
for i in range(test,test+3):
  # DEBUGG and PoC
  if i == test+2:
    img = 50*np.ones( (512//fator,512//fator) ).reshape(-1, *img_size, 1)
    # img = np.zeros( (512//fator,512//fator) ).reshape(-1, *img_size, 1)

  # test set
  else:
    path = dir_test_def + '/defeito ({}).jpeg'.format(i)
    img = cv.imread(path, cv.IMREAD_GRAYSCALE).reshape(-1, *img_size, 1)

  y_test_pred_tf.append(cnn_model.predict(img))
  y_test_pred_no_quant_tflite.append( predict_tflite(model_no_quant_tflite, img) )
  y_test_pred_tflite.append( predict_tflite(model_tflite, img) )
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f890bbf6560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f890bbf6560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Compare predictions
for i in range(len(y_test_pred_tf)):
  if i < len(y_test_pred_tf)-1:
    print('Image number', test)
  else:
    print("PoC")
  print(100*y_test_pred_tf[i][0][0])
  print(100*y_test_pred_no_quant_tflite[i][0])
  print(100*y_test_pred_tflite[i][0])
  print('\n')
  test += 1
# Out:
# Image number 704
# 99.98462200164795
# 99.98462200164795
# 99.609375
#
#
# Image number 705
# 93.33147406578064
# 93.33146810531616
# 89.0625
#
#
# PoC
# 99.99130964279175
# 99.99130964279175
# 99.609375

# %% [markdown]
# #### Quantization effect

# %%
qt_y_pred_prob = np.array(qt_y_pred_prob).reshape(len(qt_y_pred_prob),1)


differences = np.abs(qt_y_pred_prob - y_pred_prob)

print("Maximum difference = ", np.max(differences))
print("Mean difference = ", np.mean(differences))
# Out:
# Maximum difference =  0.8591938
# Mean difference =  0.1374734

# %% [markdown]
# #### Size

# %%
# Calculate size
size_tf = os.path.getsize('CNN_Casting_Inspection.hdf5')
# size_tf = os.path.getsize(MODEL_TF + '/saved_model.pb')

size_no_quant_tflite = os.path.getsize(MODEL_NO_QUANT_TFLITE)
size_tflite = os.path.getsize(MODEL_TFLITE)

# %%
# Compare size
pd.DataFrame.from_records(
    [["TensorFlow", f"{size_tf/1024} kB", ""],
     ["TensorFlow Lite", f"{size_no_quant_tflite/1024} kB ", f"(reduced by {(size_tf - size_no_quant_tflite)/1024} kB)"],
     ["TensorFlow Lite Quantized", f"{size_tflite/1024} kB", f"(reduced by {(size_no_quant_tflite - size_tflite)/1024} kB)"]],
     columns = ["Model", "Size", ""], index="Model")
# Out:
#                                       Size
# Model
# TensorFlow                    88.078125 kB
# TensorFlow Lite            11.97265625 kB   (reduced by 76.10546875 kB)
# TensorFlow Lite Quantized     8.1796875 kB   (reduced by 3.79296875 kB)

# %% [markdown]
# # Generate a TFLite Micro Model in C
# Convert the TensorFlow Lite quantized model into a C source file that can be loaded by TensorFlow Lite Micro.

# %%
# Install xxd
# !apt-get update && apt-get -qq install xxd

# Convert to a C source file
# !xxd -i {MODEL_TFLITE} > {MODEL_TFLITE_MICRO}

# Update variable names to be C compatible
REPLACE_TEXT = MODEL_TFLITE.replace('/', '_').replace('.', '_')
# !sed -i 's/'{REPLACE_TEXT}'/g_model/g' {MODEL_TFLITE_MICRO}
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,467 kB]
# Fetched 3,728 kB in 3s (1,254 kB/s)
# Reading package lists... Done

# %% [markdown]
# ## C model for Microcontroller
#
# Follow the instructions in the [hello_world](https://github.com/tensorflow/tflite-micro/blob/main/tensorflow/lite/micro/examples/hello_world) README.md for [TensorFlow Lite for MicroControllers](https://www.tensorflow.org/lite/microcontrollers/overview) to deploy this model on a specific microcontroller.
#
# ESP32 references: https://github.com/espressif/tflite-micro-esp-examples/tree/master/examples/person_detection

# %%
# Print the C source file
# !cat {MODEL_TFLITE_MICRO}
